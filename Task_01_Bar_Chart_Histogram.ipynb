# %% [markdown]
# <a href="https://colab.research.google.com/github/Ketangujare16/PRODIGY_DS_01/blob/main/Task_01_Bar_Chart_Histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'D:\Data Science Internship (prodigy infotech)\New folder\API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv', skiprows=4)
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %%
df = pd.read_csv(r'D:\Data Science Internship (prodigy infotech)\New folder\API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv', skiprows=4)

print(df.shape)
print(df.columns[:10])
df.head()
# Out:
# (266, 70)
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965'],
#       dtype='object')
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# ...

# %%
top10 = df['Country Name'].value_counts().head(10).index
filtered_df = df[df['Country Name'].isin(top10)]

plt.figure(figsize=(10, 6))
sns.countplot(x='Country Name', data=filtered_df, palette='Set2')
plt.title('Top 10 Countries by Record Count')
plt.xlabel('Country')
plt.ylabel('Number of Records')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Artharva\AppData\Local\Temp\ipykernel_18000\988737650.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Country Name', data=filtered_df, palette='Set2')

# %%
pop_2020 = df['2020'].dropna()

plt.figure(figsize=(10, 6))
sns.histplot(pop_2020, bins=30, kde=True, color='skyblue')
plt.title('Distribution of Population Across Countries (2020)')
plt.xlabel('Population')
plt.ylabel('Number of Countries')
plt.grid(True)
plt.tight_layout()
plt.show()
